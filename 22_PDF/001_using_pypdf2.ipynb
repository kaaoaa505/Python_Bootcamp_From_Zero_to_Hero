# %% [markdown]
# pip install pypdf2

# %%
import PyPDF2

# %%
pdf_file = open('test.pdf', 'rb') # rb read binary

# %%
pdf_file_reader = PyPDF2.PdfReader(pdf_file)

# %%
len(pdf_file_reader.pages)
# Out:
# 2

# %%
pdf_file_reader.pages[0]
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'],
#   '/ExtGState': {'/G3': {'/ca': 1, '/BM': '/Normal'},
#    '/G4': {'/ca': 0.102, '/BM': '/Normal'},
#    '/G6': {'/ca': 0.8118, '/BM': '/Normal'},
#    '/G32': {'/ca': 0.6, '/BM': '/Normal'},
#    '/G35': {'/ca': 0.2, '/BM': '/Normal'},
#    '/G136': {'/ca': 0.8, '/BM': '/Normal'},
#    '/G138': {'/CA': 1,
#     '/ca': 1,
#     '/LC': 0,
#     '/LJ': 0,
#     '/LW': 1,
#     '/ML': 4,
#     '/SA': True,
#     '/BM': '/Normal'},
#    '/G142': {'/ca': 0.9, '/BM': '/Normal'}},
#   '/XObject': {'/X5': {'/Type': '/XObject',
#     '/Subtype': '/Form',
#     '/Resources': {'/ProcSet': ['/PDF',
#       '/Text',
#       '/ImageB',
#       '/ImageC',
#       '/ImageI'],
#      '/ExtGState': {'/G3': {'/ca': 1, '/BM': '/Normal'},
#       '/G4': {'/ca': 0.102, '/BM': '/Normal'}}},
#     '/BBox': [0, 0, 2174, 2164],
#     '/Group': {'/Type': '/Group', '/S': '/Transparency', '/I': True},
# ...

# %%
pdf_file_reader.pages[1]
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'],
#   '/ExtGState': {'/G3': {'/ca': 1, '/BM': '/Normal'},
#    '/G4': {'/ca': 0.102, '/BM': '/Normal'},
#    '/G6': {'/ca': 0.8118, '/BM': '/Normal'},
#    '/G32': {'/ca': 0.6, '/BM': '/Normal'},
#    '/G35': {'/ca': 0.2, '/BM': '/Normal'},
#    '/G48': {'/CA': 1,
#     '/ca': 1,
#     '/LC': 0,
#     '/LJ': 0,
#     '/LW': 0.60000002,
#     '/ML': 4,
#     '/SA': True,
#     '/BM': '/Normal'},
#    '/G136': {'/ca': 0.8, '/BM': '/Normal'},
#    '/G142': {'/ca': 0.9, '/BM': '/Normal'},
#    '/G164': {'/CA': 1,
#     '/ca': 1,
#     '/LC': 1,
#     '/LJ': 0,
#     '/LW': 1,
#     '/ML': 4,
#     '/SA': True,
#     '/BM': '/Normal'},
#    '/G168': {'/ca': 0.651, '/BM': '/Normal'},
#    '/G172': {'/ca': 0.81, '/BM': '/Normal'}},
#   '/XObject': {'/X162': {'/Type': '/XObject',
#     '/Subtype': '/Form',
#     '/Resources': {'/ProcSet': ['/PDF',
#       '/Text',
#       '/ImageB',
# ...

# %%
page_1 = pdf_file_reader.pages[0].extract_text()
print(page_1)
# Out:
# System Information
# System hostname tvb (127.0.1.1)  (/net/list_dns.cgi)
# Oper ating system Ubuntu Linux 24.04.1
# Webmin v ersion 2.202
# Authentic theme v ersion 21.20.7
# Time on system Thursda y, December 26, 2024 1:55 PM  (/time/)
# Kernel and CPU Linux 6.8.0-51-generic on x86_64
# Processor information 11th Gen Intel(R) Cor e(TM) i7-1165G7 @ 2.80GHz, 8 cor es
# System uptime 5 hours, 00 minutes  (/init/)
# Running pr ocesses 331 (/pr oc/index_tr ee.cgi)
# CPU load a verages 1.23 (1 min) 0.34 (5 mins) 0.17 (15 mins)
# Real memor y 2.19 GiB used / 1.9 GiB cached / 4.68 GiB t otal
# Virtual memor y 133.43 MiB used / 3.72 GiB t otal
# Local disk space 33.75 GiB used / 15.16 GiB fr ee / 48.91 GiB t otal
# Package updates All installed packages ar e up t o date  (/package-updates/index.cgi?mode=updates)
# Stats Hist ory
# CPU
# 1:35 PM
# 1:37 PM
# 1:38 PM
# 1:40 PM
# 1:42 PM
# 1:43 PM
# 1:45 PM050%100%
# Real Memor y
# 1:35 PM
# 1:37 PM
# 1:38 PM
# 1:40 PM
# 1:42 PM
# 1:43 PM
# ...

# %%
page_2 = pdf_file_reader.pages[1].extract_text()
print(page_2)
# Out:
# Process
# 1:35 PM
# 1:37 PM
# 1:38 PM
# 1:40 PM
# 1:42 PM
# 1:43 PM
# 1:45 PM0200400
# Disk I/O
# 1:35 PM
# 1:37 PM
# 1:38 PM
# 1:40 PM
# 1:42 PM
# 1:43 PM
# 1:45 PM02 MiB4 MiB
# Network I/O
# 1:35 PM
# 1:37 PM
# 1:38 PM
# 1:40 PM
# 1:42 PM
# 1:43 PM
# 1:45 PM0800 Kbps2 Mbps
# Recent Logins
# IP addr ess Last activ e at State Actions
# ::1 12/26/2024 01:55 PM This login
# Network Inter faces
# Name Type Inter face Speed IPv4 Addr ess IPv6 Addr esses Netmask Broadcast Activ e
# enp0s3 Ethernet 1000Mb/s 10.0.2.15fd00::b8ba:7a8e:db66:52d5
# fd00::a00:27ff:f e1b:b8f9
# fe80::a00:27ff:f e1b:b8f9255.255.255.0 10.0.2.255 Activ e
# Disk Usage
# Mounted As Type Free Used Total Device ID
# / ext432% (15.15 GiB)
# 80% (2594237 inodes)31.24 GiB
# 682563 inodes48.91 GiB
# 3276800 inodes/dev/disk/b y-uuid/225d8b60-8
# 12/26/24, 1:55 PM Dashboard — Webmin 2.202 (Ubuntu Linux 24.04.1)
# localhost:81/sysinfo.cgi?xnavigation=1 2/2

# %%
pdf_file.close()
